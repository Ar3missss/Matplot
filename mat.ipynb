# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

# %% [markdown]
# Basic Graph

# %%
sheet=pd.read_excel('/Users/macbookair/Python/matplot/Book1.xlsx')
# Out:
# /Users/macbookair/Python/matplot/env/bin/python

# %%
x=[1,2,3]
y=[4,5,6]

plt.plot(x,y)
plt.title('Our First Graph')
plt.show()
