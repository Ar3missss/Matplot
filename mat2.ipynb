# %%
import matplotlib.pyplot as plt
import pandas as pd 

gas = pd.read_csv('data/gas_prices.csv')
petrol =gas.copy()

plt.title('Gas Prices Over Time (in USD)')

# Without Loop
plt.plot(gas.Year,gas.USA , 'g.-' , label ='USA') # here 'b.-' is color,marker,line
plt.plot(gas.Year,gas.UK , 'b.-', label ='UK')
plt.plot(gas.Year,gas.France ,'r.-' , label ='France')
plt.plot(gas.Year ,gas.Germany , 'y.-', label ='Germany')
plt.plot(gas.Year ,gas.Japan , '.-', label ='Japan')

plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.savefig('outputs/gas_prices.png',dpi =300)

plt.legend()
plt.show()

# %%
# With Loop
petrol =gas.copy()
plt.title('Petrol Prices Over Time (in USD)')

for country in petrol:
    if country != 'Year': # we do this bcz we dont want that Country = Year it will make diagonal line ggraph will be useless
        plt.plot(petrol.Year,petrol[country] , label =country, marker = '.')

plt.xticks(petrol.Year[::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.savefig('outputs/petrol_prices.png',dpi =300)

plt.legend(bbox_to_anchor = (1,1)) # position of legends
plt.show()

# %%
petrol.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11
